# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
# Your code goes here

import pandas as pd 
url1 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv'
url2 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv'
url3 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv'

df_1 = pd.read_csv(url1)
df_2 = pd.read_csv(url2)
df_3 = pd.read_csv(url3)

# %%
def explorar_df(df):
    print(df.info())

    print('Primeras filas')
    print(df.head())

    print('Describe()')
    print(df.describe(include='all').T)

    print('Nulos')
    nulos = df.isnull().sum()
    print(nulos[nulos > 0] if nulos.any() else 'Notnnull')

    print('Duplicados')
    print(df.duplicated().sum())
    
    print('Tamaño')
    print(f"Filas: {df.shape[0]} | Columnas: {df.shape[1]}")

# %%
## Esta función está a partir de la segunda limpieza, redactada a partir de los pasos de limpieza del dataset 1 
def limpiar_dataset(df):
    df_clean = df.copy()
    df_clean.columns = (df_clean.columns
                        .str.strip()
                        .str.lower()
                        .str.replace(' ', '_')
                        .str.replace('.', '', regex=False))
    df_clean.duplicated().sum()
    df_clean = df_clean.drop_duplicates()
    df_clean = df_clean.dropna(how='all')

    return df_clean

# %% [markdown]
# ## LIMPIEZA

# %% [markdown]
# ### Limpieza 1:

# %%
df_1.head()
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
explorar_df(df_1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4008 entries, 0 to 4007
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer                   1071 non-null   object
#  1   ST                         1071 non-null   object
#  2   GENDER                     954 non-null    object
#  3   Education                  1071 non-null   object
#  4   Customer Lifetime Value    1068 non-null   object
#  5   Income                     1071 non-null   float64
#  6   Monthly Premium Auto       1071 non-null   float64
#  7   Number of Open Complaints  1071 non-null   object
#  8   Policy Type                1071 non-null   object
#  9   Vehicle Class              1071 non-null   object
#  10  Total Claim Amount         1071 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 344.6+ KB
# None
# Primeras filas
# ...

# %%
## Eliminamos duplicados
df_1 = df_1.drop_duplicates()

# %%
## Verificamos
df_1.duplicated().sum()
# Out:
# np.int64(0)

# %%
## Comprobamos nulos
df_1.isnull().sum()
# Out:
# Customer                       1
# ST                             1
# GENDER                       118
# Education                      1
# Customer Lifetime Value        4
# Income                         1
# Monthly Premium Auto           1
# Number of Open Complaints      1
# Policy Type                    1
# Vehicle Class                  1
# Total Claim Amount             1
# dtype: int64

# %%
## Eliminamos nulos 
df_1 = df_1.dropna()

# %%
## Verificamos 
df_1.isnull().sum()
# Out:
# Customer                     0
# ST                           0
# GENDER                       0
# Education                    0
# Customer Lifetime Value      0
# Income                       0
# Monthly Premium Auto         0
# Number of Open Complaints    0
# Policy Type                  0
# Vehicle Class                0
# Total Claim Amount           0
# dtype: int64

# %%
## Comprobamos los valores únicos para unificar aquellas coumnas que necesiten unificase como Gender o State. 
df_1.nunique()
# Out:
# Customer                     952
# ST                             8
# GENDER                         5
# Education                      6
# Customer Lifetime Value      921
# Income                       688
# Monthly Premium Auto         128
# Number of Open Complaints      6
# Policy Type                    3
# Vehicle Class                  6
# Total Claim Amount           688
# dtype: int64

# %% [markdown]
# #### Gestión de unificación

# %%
df_1['ST'].unique()
# Out:
# array(['Arizona', 'Nevada', 'California', 'Washington', 'Oregon', 'AZ',
#        'WA', 'Cali'], dtype=object)

# %%
## Unificamos valores de State
df_1['ST'] = df_1['ST'].replace({
    'WA' : 'Washington',
    'Cali': 'California',
    'AZ': 'Arizona'
    })

# %%
## Verificamos 
df_1['ST'].unique()
# Out:
# array(['Arizona', 'Nevada', 'California', 'Washington', 'Oregon'],
#       dtype=object)

# %%
df_1['GENDER'].unique()
# Out:
# array(['F', 'M', 'Femal', 'Male', 'female'], dtype=object)

# %%
df_1['GENDER'] = df_1['GENDER'].replace({
    'Femal' : 'F',
    'Male': 'M',
    'female': 'F'
    })

# %%
## Verificamos
df_1['GENDER'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df_1 = df_1.dropna()

# %% [markdown]
# #### Unificamos nombres de columnas

# %%
df_1.columns = df_1.columns.str.lower().str.replace(' ', '_')

# %%
## Verificamos 
df_1.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'vehicle_class', 'total_claim_amount'],
#       dtype='object')

# %% [markdown]
# ## Limpieza 2

# %%
explorar_df(df_2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 996 entries, 0 to 995
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer                   996 non-null    object
#  1   ST                         996 non-null    object
#  2   GENDER                     991 non-null    object
#  3   Education                  996 non-null    object
#  4   Customer Lifetime Value    992 non-null    object
#  5   Income                     996 non-null    int64
#  6   Monthly Premium Auto       996 non-null    int64
#  7   Number of Open Complaints  996 non-null    object
#  8   Total Claim Amount         996 non-null    float64
#  9   Policy Type                996 non-null    object
#  10  Vehicle Class              996 non-null    object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 85.7+ KB
# None
# Primeras filas
# ...

# %%
df_clean_2 = limpiar_dataset(df_2)

# %%
df_clean_2.head()
# Out:
#   customer          st gender education customer_lifetime_value  income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    monthly_premium_auto number_of_open_complaints  total_claim_amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       policy_type  vehicle_class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
df_clean_2.nunique()
# Out:
# customer                     996
# st                             6
# gender                         4
# education                      6
# customer_lifetime_value      950
# income                       733
# monthly_premium_auto         126
# number_of_open_complaints      6
# total_claim_amount           667
# policy_type                    3
# vehicle_class                  6
# dtype: int64

# %%
df_clean_2['st'].unique()
# Out:
# array(['Arizona', 'California', 'Oregon', 'Nevada', 'Washington', 'AZ'],
#       dtype=object)

# %%
df_clean_2['st'] = df_clean_2['st'].replace({
    'AZ' : 'Arizona'})

# %%
df_clean_2['gender'].unique()
# Out:
# array(['F', 'M', nan, 'female', 'Male'], dtype=object)

# %%
df_clean_2['gender'] = df_clean_2['gender'].replace ({
    'female': 'F',
    'Male': 'M'
})

# %%
df_clean_2 = df_clean_2.dropna()

# %% [markdown]
# ## Limpieza 3

# %%
explorar_df(df_3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7070 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer                   7070 non-null   object
#  1   State                      7070 non-null   object
#  2   Customer Lifetime Value    7070 non-null   float64
#  3   Education                  7070 non-null   object
#  4   Gender                     7070 non-null   object
#  5   Income                     7070 non-null   int64
#  6   Monthly Premium Auto       7070 non-null   int64
#  7   Number of Open Complaints  7070 non-null   int64
#  8   Policy Type                7070 non-null   object
#  9   Total Claim Amount         7070 non-null   float64
#  10  Vehicle Class              7070 non-null   object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 607.7+ KB
# None
# Primeras filas
# ...

# %%
df_clean_3 = limpiar_dataset(df_3)

# %%
df_clean_3.head()
# Out:
#   customer       state  customer_lifetime_value             education gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    income  monthly_premium_auto  number_of_open_complaints    policy_type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    total_claim_amount  vehicle_class
# ...

# %%
df_clean_3.nunique()
# Out:
# customer                     7070
# state                           5
# customer_lifetime_value      6288
# education                       5
# gender                          2
# income                       4463
# monthly_premium_auto          194
# number_of_open_complaints       6
# policy_type                     3
# total_claim_amount           4025
# vehicle_class                   6
# dtype: int64

# %% [markdown]
# ## Unificamos nombres de columnas para no tener problemas con el merge

# %%
df_1.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'vehicle_class', 'total_claim_amount'],
#       dtype='object')

# %%
df_clean_2.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'total_claim_amount', 'policy_type', 'vehicle_class'],
#       dtype='object')

# %%
df_clean_3.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'education', 'gender',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'total_claim_amount', 'vehicle_class'],
#       dtype='object')

# %%
df_clean_3 = df_clean_3.rename(columns={'state': 'st'})

# %% [markdown]
# ## Unimos los tres datasets

# %%
## Decidimos unir con outer merge porque queremos conservar todos los valores de las tablas independientemente de si coinciden o no.

# %%
df_1y2 = pd.merge(df_1, df_clean_2, how = 'outer')

# %%
## Comprobamos que los tipos de todas las columnas funcionen igual en todas, para no tener conflictos en el merge. Además decidimos qué nos interesará más según nuestras hipótesis.

# %%
df_1y2.dtypes
# Out:
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer_lifetime_value       object
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object

# %%
df_clean_3.dtypes
# Out:
# customer                      object
# st                            object
# customer_lifetime_value      float64
# education                     object
# gender                        object
# income                         int64
# monthly_premium_auto           int64
# number_of_open_complaints      int64
# policy_type                   object
# total_claim_amount           float64
# vehicle_class                 object
# dtype: object

# %%
new_types = {
    'customer_lifetime_value' :'object',
    'income': 'float64',
    'monthly_premium_auto': 'float64',
    'number_of_open_complaints': 'object'
}
df_clean_3 = df_clean_3.astype(new_types)

# %%
##Verificamos que se han efectuado los cambios 
df_clean_3.dtypes
# Out:
# customer                      object
# st                            object
# customer_lifetime_value       object
# education                     object
# gender                        object
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# total_claim_amount           float64
# vehicle_class                 object
# dtype: object

# %%
df_final = pd.merge(df_1y2, df_clean_3, how = 'outer')

# %%
explorar_df(df_final)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9007 entries, 0 to 9006
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   9007 non-null   object
#  1   st                         9007 non-null   object
#  2   gender                     9007 non-null   object
#  3   education                  9007 non-null   object
#  4   customer_lifetime_value    9007 non-null   object
#  5   income                     9007 non-null   float64
#  6   monthly_premium_auto       9007 non-null   float64
#  7   number_of_open_complaints  9007 non-null   object
#  8   policy_type                9007 non-null   object
#  9   vehicle_class              9007 non-null   object
#  10  total_claim_amount         9007 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 774.2+ KB
# None
# Primeras filas
# ...

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
url_mkt = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv'
df_mkt = pd.read_csv(url_mkt)

# %%
explorar_df(df_mkt)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   unnamed:_0                     10910 non-null  int64
#  1   customer                       10910 non-null  object
#  2   state                          10910 non-null  object
#  3   customer_lifetime_value        10910 non-null  float64
#  4   response                       10910 non-null  object
#  5   coverage                       10910 non-null  object
#  6   education                      10910 non-null  object
#  7   effective_to_date              10910 non-null  object
#  8   employmentstatus               10910 non-null  object
#  9   gender                         10910 non-null  object
#  10  income                         10910 non-null  int64
#  11  location_code                  10910 non-null  object
# ...

# %%
df_mkt = limpiar_dataset(df_mkt)

# %%
df_mkt.nunique()
# Out:
# unnamed:_0                       10910
# customer                          9134
# state                                5
# customer_lifetime_value           8041
# response                             2
# coverage                             3
# education                            5
# effective_to_date                   59
# employmentstatus                     5
# gender                               2
# income                            5694
# location_code                        3
# marital_status                       3
# monthly_premium_auto               202
# months_since_last_claim             37
# months_since_policy_inception      100
# number_of_open_complaints            7
# number_of_policies                   9
# policy_type                          3
# policy                               9
# renew_offer_type                     4
# sales_channel                        4
# total_claim_amount                5106
# vehicle_class                        6
# ...

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %%
ventas_summ = df_mkt.pivot_table(index='sales_channel',
                                 values = 'total_claim_amount',
                                 aggfunc='sum').round(2)

# %%
ventas_summ
# Out:
#                   income
# sales_channel
# Agent          152490152
# Branch         113775608
# Call Center     81055004
# Web             62200103

# %% [markdown]
# ##### La mayor cantidad de ventas viene dada por la venta por agentes, 152.49 millones. Esto confirma que los agentes no solo traen más volumen, sino que gestionan la mayor masa de ingresos de la compañía. El canal Branch se mantiene sólido en segundo lugar con 113.77 millones. Hay una diferencia de casi 40 millones respecto a los agentes, lo que refuerza la idea de que la fuerza de ventas externa (agentes) es más productiva que la oficina física.

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
insight = df_mkt.pivot_table(index = 'gender',
                             columns = 'education',
                             values ='customer_lifetime_value',
                             aggfunc= 'mean').round(2)

# %%
insight
# Out:
# education  Bachelor  College   Doctor  High School or Below   Master
# gender
# F           7874.27  7748.82  7328.51               8675.22  8157.05
# M           7703.60  8052.46  7415.33               8149.69  8168.83

# %% [markdown]
# #### El Customer Lifetime Value medio se mantiene relativamente equilibrado entre géneros, aunque con variaciones interesantes según el nivel educativo: el segmento con educación Master presenta los valores más altos y consistentes en ambos géneros mientras que el grupo de High School or Below destaca especialmente en las mujeres, alcanzando el promedio más alto de toda la tabla.

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
complaints = df_mkt.pivot_table(index = 'month',
                                columns = 'policy_type',
                                values='number_of_open_complaints',
                                aggfunc='sum').reset_index()

# %%
formato = pd.melt(complaints, 
                      id_vars=['month'], 
                      var_name='policy_type', 
                      value_name='number_of_open_complaints')

# %%
formato
# Out:
#    month     policy_type  number_of_open_complaints
# 0      1  Corporate Auto                 443.434952
# 1      2  Corporate Auto                 385.208135
# 2      1   Personal Auto                1727.605722
# 3      2   Personal Auto                1453.684441
# 4      1    Special Auto                  87.074049
# 5      2    Special Auto                  95.226817
